# %% [markdown]
# # Ecommerce Purchases Exercise
#
# In this Exercise you will be given some Fake Data about some purchases done through Amazon! Just go ahead and follow the directions and try your best to answer the questions and complete the tasks. Feel free to reference the solutions. Most of the tasks can be solved in different ways. For the most part, the questions get progressively harder.
#
# Please excuse anything that doesn't make "Real-World" sense in the dataframe, all the data is fake and made-up.
#
# Also note that all of these questions can be answered with one line of code.
# ____
# ** Import pandas and read in the Ecommerce Purchases csv file and set it to a DataFrame called ecom. **

# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("https://query.data.world/s/4owa6sc3rsd5rgt2327dsguo3b5psy")

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
data.shape
# Out:
# (10000, 14)

# %%
data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5     7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6        93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7     260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8               2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
# 10        650 Elizabeth Park\nLake Maria, LA 13526-2530  65 Yn       PM
# 11               349 Laurie Parks\nThomasview, ID 08970  30 kK       PM
# ...

# %% [markdown]
# ** How many rows and columns are there? **

# %%
data.shape
# Out:
# (10000, 14)

# %% [markdown]
# ** What is the average Purchase Price? **

# %%
data['Purchase Price'].mean()
# Out:
# 50.347302

# %% [markdown]
# ** What were the highest and lowest purchase prices? **

# %%
data['Purchase Price'].max()
# Out:
# 99.99

# %%
data['Purchase Price'].min()
# Out:
# 0.0

# %% [markdown]
# ** How many people have English 'en' as their Language of choice on the website? **

# %%
data[data['Language']=='en']['Email'].count()
# Out:
# 1098

# %% [markdown]
# ** How many people have the job title of "Lawyer" ? **

# %%
data[data['Job']=='Lawyer'].groupby('Job').size()
# Out:
# Job
# Lawyer    30
# dtype: int64

# %% [markdown]
# ** How many people made the purchase during the AM and how many people made the purchase during PM ? **
#
# **(Hint: Check out [value_counts()](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html) ) **

# %%
print(data[data['AM or PM']=='AM']['AM or PM'].value_counts())
print(data[data['AM or PM']=='PM']['AM or PM'].value_counts())
# Out:
# AM    4932
# Name: AM or PM, dtype: int64
# PM    5068
# Name: AM or PM, dtype: int64

# %% [markdown]
# ** What are the 5 most common Job Titles? **

# %%
data['Job'].value_counts().head()
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Designer, jewellery              27
# Purchasing manager               27
# Name: Job, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
# Address             10000 non-null object
# Lot                 10000 non-null object
# AM or PM            10000 non-null object
# Browser Info        10000 non-null object
# Company             10000 non-null object
# Credit Card         10000 non-null int64
# CC Exp Date         10000 non-null object
# CC Security Code    10000 non-null int64
# CC Provider         10000 non-null object
# Email               10000 non-null object
# Job                 10000 non-null object
# IP Address          10000 non-null object
# Language            10000 non-null object
# Purchase Price      10000 non-null float64
# size                0 non-null float64
# dtypes: float64(2), int64(2), object(11)
# memory usage: 742.2+ KB

# %% [markdown]
# ** Someone made a purchase that came from Lot: "90 WT" , what was the Purchase Price for this transaction? **

# %%
data[data['Lot']=='90 WT']['Purchase Price']
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %% [markdown]
# ** What is the email of the person with the following Credit Card Number: 4926535242672853 **

# %%
data[data['Credit Card']==4926535242672853]['Email']
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %% [markdown]
# ** How many people have American Express as their Credit Card Provider *and* made a purchase above $95 ?**

# %%
data[data['CC Provider']=='American Express']['CC Provider'].value_counts()
# Out:
# American Express    849
# Name: CC Provider, dtype: int64

# %%
data[(data['CC Provider']=='American Express') & (data['Purchase Price']>95)]['CC Provider'].value_counts()
# Out:
# American Express    39
# Name: CC Provider, dtype: int64

# %% [markdown]
# ** Hard: How many people have a credit card that expires in 2025? **

# %%
data[data['CC Exp Date'].str.contains('/25')]['CC Exp Date'].value_counts().sum()
# Out:
# 1033

# %%
data.head(2)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
#
#    CC Security Code   CC Provider               Email  \
# 0               900  JCB 16 digit   pdunlap@yahoo.com
# 1               561    Mastercard  anthony41@reed.com
#
#                                       Job       IP Address Language  \
# 0  Scientist, product/process development  149.146.147.205       el
# 1                       Drilling engineer     15.160.41.51       fr
#
# ...

# %% [markdown]
# ** Hard: What are the top 5 most popular email providers/hosts (e.g. gmail.com, yahoo.com, etc...) **

# %%
data['Index'] = map(lambda x: x.str.find('@'), data['Email'])

# %%
data.head(1)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
#
#                                         Browser Info          Company  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...  Martinez-Herman
#
#         Credit Card CC Exp Date  CC Security Code   CC Provider  \
# 0  6011929061123406       02/20               900  JCB 16 digit
#
#                Email                                     Job       IP Address  \
# 0  pdunlap@yahoo.com  Scientist, product/process development  149.146.147.205
#
#   Language  Purchase Price  Index
# 0       el           98.14      7

# %%
data['Index']=data['Email'].str.find('@')

# %%
data[data['Email'].str.slice(data['Index'])]

# %%
a=data['Email'].str.slice(data['Index'])

# %%
data.shape
# Out:
# (10000, 14)

# %%
dataProvider=data['Email'].str.split('@', n = 0, expand = True)

# %%
data['Provider']=dataProvider[1]

# %%
dataset=data['Provider'].value_counts().head()

# %%
dataset
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Provider, dtype: int64

# %% [markdown]
# ### Data Visualization
#
# ** Implement a bar plot for top 5 most popular email providers/hosts **

# %%
dataset.plot(kind='barh')

# %% [markdown]
# ** Plot distribution of Purchase Price **

# %%
sns.distplot(data['Purchase Price'])
# Out:
# c:\users\acer\myenv\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ** Implement countplot on Language **

# %%
dataLanguage=data['Language'].value_counts()

# %%
dataLanguage
# Out:
# ru    1155
# de    1155
# el    1137
# pt    1118
# en    1098
# fr    1097
# es    1095
# it    1086
# zh    1059
# Name: Language, dtype: int64

# %%
sns.countplot(x='Language',data=data)

# %%
Feel free to plot more graphs to dive deeper into the dataset.

# %%
dataTit=pd.read_csv('https://query.data.world/s/f5hxtamju22yjjfhogtdem2uk6twif')

# %%
dataTit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
dataTit.shape
# Out:
# (891, 12)

# %%
dataSex=dataTit['Sex'].value_counts()

# %%
dataSurv=dataTit['Survived'].value_counts()

# %%
dataTit['Fare'].min()
# Out:
# 0.0

# %%
dataTit['Fare'].mean()
# Out:
# 32.204207968574636

# %%
dataTit['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
dataTit['Pclass'].value_counts()

# %%
dataSex.plot(kind='bar')

# %%
dataSurv.plot(kind='barh')

# %%
datSexSuv=dataTit[['Sex','Survived']]

# %%
datSexSuv[datSexSuv['Survived']==0]['Sex'].value_counts()
# Out:
# male      468
# female     81
# Name: Sex, dtype: int64

# %%
datSexSuv[datSexSuv['Survived']==1]['Sex'].value_counts()
# Out:
# female    233
# male      109
# Name: Sex, dtype: int64

# %%
sns.countplot(x='Sex',data=dataTit,hue='Survived')

# %%
sns.countplot(x='Pclass',data=dataTit,hue='Survived')

# %%
sns.distplot(datSexSuv[datSexSuv['Survived']==1]['Sex'].value_counts())
sns.distplot(datSexSuv[datSexSuv['Survived']==0]['Sex'].value_counts());

# %% [markdown]
# # Great Job!
